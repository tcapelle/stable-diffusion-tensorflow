# %%
from PIL import Image
from types import SimpleNamespace
from stable_diffusion_tf.stable_diffusion import get_model, text2image

# %%
args = SimpleNamespace(H=512, W=512, steps=5, scale=7.5, temp=1)

# %%
text_encoder, diffusion_model, decoder = get_model(args.H, args.W, download_weights=True)

# %%
prompt = "An unicorn dancing in the street of Tokyo"

# %%
img = text2image(prompt, 
	img_height=args.H, 
	img_width=args.W,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder,  
	batch_size=1, 
	n_steps=args.steps, 
	unconditional_guidance_scale =args.scale , 
	temperature = 1
)
# Out:
# running for [1, 201, 401, 601, 801] timesteps
#   0   1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.57s/it]

# %%
pil_img = Image.fromarray(img[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
img = text2image(prompt, 
	img_height=args.H, 
	img_width=args.W,  
	text_encoder=text_encoder, 
	diffusion_model=diffusion_model, 
	decoder=decoder,  
	batch_size=1, 
	n_steps=args.steps, 
	unconditional_guidance_scale =args.scale , 
	temperature = 1
)
# Out:
# running for [1, 201, 401, 601, 801] timesteps
#   0   1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.59s/it]

# %%
pil_img = Image.fromarray(img[0])
pil_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
